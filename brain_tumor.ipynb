# %%
from ultralytics import YOLO

# Load the nano model
model = YOLO('yolov8n.pt')

# Train the model for 50 epochs with an image size of 640
results = model.train(
    data='./datasets/brain-tumor/brain-tumor.yaml',
    epochs=50,
    imgsz=640
)
# Out:
# Ultralytics 8.4.69  Python-3.12.13 torch-2.12.0+cpu CPU (11th Gen Intel Core i5-1145G7 @ 2.60GHz)
# ...
